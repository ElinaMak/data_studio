# %% [markdown]
# # Why is wine expensive in New York?
#
# …wonders a European in US.
#
# A fast answer could be because New York is not California as the Bear Flag State produces an average of 85 percent of total U.S. wine production.
#
# For someone coming from Europe, 10$, 14$ dollars (and going up) for not even a standard glass of cheap “house” wine, is almost the double price of a standard glass of wine in most European countries.
# We known prices are determined by supply and demand so it makes sense to examine the financial data of the American wine market.
#
# For this research, I built a dataset which combines data from different sources but mainly from the wineinstitute.org.
#
# The charts I use are simple bar charts because I believe they are more easy to grasp for the audience and pass the message directly.
#
# Let’s see some of them:
#
# *Below are just the plots, there is another file  on github with accompanying text with more information about US and wine.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('Wine.csv')
df.head()
# Out:
#    Year  California Production   U.S. Production
# 0  2016                    680               806
# 1  2015                    638               768
# 2  2014                    709               835
# 3  2013                    728               836
# 4  2012                    662               752

# %%
df.dtypes
# Out:
# Year                     int64
# California Production    int64
#  U.S. Production         int64
# dtype: object

# %%
small_df = df.head()
small_df
# Out:
#    Year  California Production   U.S. Production
# 0  2016                    680               806
# 1  2015                    638               768
# 2  2014                    709               835
# 3  2013                    728               836
# 4  2012                    662               752

# %%
small_df.plot(kind='bar', x='Year', y=' U.S. Production')

# %%
small_df.plot(kind='bar', x='Year', y='California Production')

# %%
ax = small_df.plot(kind='barh', x='Year', stacked=True, figsize=(10, 3), title="Wine production in US")

# %%
plt.style.use('fivethirtyeight')
ax = small_df.plot(kind='barh', x='Year', figsize=(10, 5), title="Wine production in US")
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, fancybox=True, shadow=True)

# %%
ax = small_df.plot(kind='bar', x='Year', figsize=(10, 5), title="Wine production in US")
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, fancybox=True, shadow=True)

# %%
ax = small_df.plot(kind='barh', x='Year', figsize=(10, 5), title="Wine production in US")
ax.title.set_fontsize(30)
ax.set_xlabel('Volume in Gallons', fontsize=25,fontname="Arial Unicode MS")
ax.set_ylabel('Year',fontsize=22,fontname="Arial Unicode MS")
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, fancybox=True, shadow=True)

# %%
ax = small_df.plot(kind='bar', x='Year', figsize=(10, 5), title="Wine production in US")
ax.title.set_fontsize(35)
ax.set_ylabel('Volume in Gallons',fontsize=20,fontname="Arial Unicode MS") 
ax.set_xlabel('Year',fontsize=25,fontname="Arial Unicode MS") 

ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, fancybox=True, shadow=True)

# %%
#move legend out of the plot
from matplotlib.font_manager import FontProperties

fontP = FontProperties()
fontP.set_size('small')

ax = small_df.plot(kind='bar', x='Year', figsize=(10, 5), title="Wine production in US")
ax.title.set_fontsize(30)
ax.set_ylabel('Volume in Gallons',fontsize=20,fontname="Arial Unicode MS") 
ax.set_xlabel('Year',fontsize=25,fontname="Arial Unicode MS") 

ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, fancybox=True, shadow=True)

#ax.legend."title", prop=fontP)

# %%
#not very representing
small_df.plot(x="California Production", y=" U.S. Production", kind='bar')

# %%
ax = small_df.plot(x="Year", y=" U.S. Production", kind='bar')
ax.legend().set_visible(False)

# %%
df2 = pd.read_csv('winedollars.csv')
df2.head()
# Out:
#    Year  California Production  U.S. Production  Exports in Gallons  \
# 0  2016                    680              806                 109
# 1  2015                    638              768                 121
# 2  2014                    709              835                 117
# 3  2013                    728              836                 115
# 4  2012                    662              752                 107
#
#    Exports Revenue Dollars
# 0               1620000000
# 1               1603000000
# 2               1494000000
# 3               1553000000
# 4               1336000000

# %%
small_df2 = df2.head()
small_df2
# Out:
#    Year  California Production  U.S. Production  Exports in Gallons  \
# 0  2016                    680              806                 109
# 1  2015                    638              768                 121
# 2  2014                    709              835                 117
# 3  2013                    728              836                 115
# 4  2012                    662              752                 107
#
#    Exports Revenue Dollars
# 0               1620000000
# 1               1603000000
# 2               1494000000
# 3               1553000000
# 4               1336000000

# %%
plt.style.use('seaborn-dark-palette')

# %%
ax = small_df2.plot(kind='bar', x='Year', y='Exports in Gallons')
ax.legend().set_visible(False)

# %%
#need to correct this
from matplotlib.ticker import FuncFormatter

def with_commas(value, pos):
   millions = (value/1000000000)
   return "{}".format(millions)

formatter = FuncFormatter(with_commas)

ax2 = small_df2.plot(kind='barh', x='Year', y='Exports Revenue Dollars', figsize=(10, 5), title="American Wine Exports")
ax2.xaxis.set_major_formatter(formatter)
ax2.set_ylabel('Year',fontsize=25,fontname="Arial Unicode MS")
ax2.set_xlabel('Billions',fontsize=25,fontname="Arial Unicode MS")
ax2.legend().set_visible(False)
plt.gca().invert_yaxis()

# %%
plt.style.use('fivethirtyeight')

# %%
from matplotlib.ticker import FuncFormatter

def with_commas(value, pos):
   millions = (value/1000000000)
   return "{}".format(millions)

formatter = FuncFormatter(with_commas)

ax2 = small_df2.plot(kind='barh', x='Year', y='Exports Revenue Dollars', figsize=(10, 5), title="American Wine Exports")
ax2.xaxis.set_major_formatter(formatter)
ax2.set_ylabel('Year',fontsize=25,fontname="Arial Unicode MS")
ax2.set_xlabel('Value in billions of dollars', fontsize=25,fontname="Arial Unicode MS")
ax2.legend().set_visible(False)
plt.gca().invert_yaxis()

# %%
ax3 = small_df2.plot(kind='barh', x='Year', y='Exports in Gallons', figsize=(10, 5), title="American Wine Exports in Gallons")
ax3.set_ylabel('Year',fontsize=20,fontname="Arial Unicode MS")
ax3.set_xlabel('Exports in Gallons (millions)',fontsize=20,fontname="Arial Unicode MS")
ax3.legend().set_visible(False)
plt.gca().invert_yaxis()

# %%
ax3 = small_df2.plot(kind='bar', x='Year', y='Exports in Gallons', figsize=(10, 5), title="American Wine Exports in Gallons")
ax3.set_ylabel('Exports in Gallons',fontsize=20,fontname="Arial Unicode MS")
ax3.set_xlabel('Year',fontsize=20,fontname="Arial Unicode MS")
ax3.legend().set_visible(False)

# %%
small_df2.dtypes
# Out:
# Year                       int64
# California Production      int64
# U.S. Production            int64
# Exports in Gallons         int64
# Exports Revenue Dollars    int64
# dtype: object

# %%
#correct the point in the numbers
small_df2['Year_date'] = pd.to_datetime(small_df2['Year'], format="%Y")
small_df2.head()
# Out:
# /Users/elinamakri/.pyenv/versions/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    Year  California Production  U.S. Production  Exports in Gallons  \
# 0  2016                    680              806                 109
# 1  2015                    638              768                 121
# 2  2014                    709              835                 117
# 3  2013                    728              836                 115
# 4  2012                    662              752                 107
#
#    Exports Revenue Dollars  Year_date
# 0               1620000000 2016-01-01
# 1               1603000000 2015-01-01
# 2               1494000000 2014-01-01
# 3               1553000000 2013-01-01
# ...

# %%
ax3 = small_df2.plot(kind='bar', x='Year', y='Exports in Gallons', figsize=(10, 5), rot=0, title="American Wine Exports in Gallons")
ax3.set_ylabel('Exports in Gallons',fontsize=25,fontname="Arial Unicode MS")
ax3.set_xlabel('Year',fontsize=25,fontname="Arial Unicode MS")
ax3.legend().set_visible(False)

# %%
#there is smth wrong with 2016 number...
small_df2.plot(kind='line', x='Year_date', y='Exports in Gallons', figsize=(10, 5), title="American Wine Exports in Gallons")
ax3.set_xlabel('Year_date',fontsize=30,fontname="Arial Unicode MS")
ax3.set_ylabel('Exports in Gallons',fontsize=30,fontname="Arial Unicode MS")
# Out:
# Text(30.2,0.5,'Exports in Gallons')
